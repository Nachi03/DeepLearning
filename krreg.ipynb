# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('../DATA/kc_house_data.csv')

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.corr()['price']
# Out:
# id              -0.016772
# price            1.000000
# bedrooms         0.308787
# bathrooms        0.525906
# sqft_living      0.701917
# sqft_lot         0.089876
# floors           0.256804
# waterfront       0.266398
# view             0.397370
# condition        0.036056
# grade            0.667951
# sqft_above       0.605368
# sqft_basement    0.323799
# yr_built         0.053953
# yr_renovated     0.126424
# zipcode         -0.053402
# lat              0.306692
# long             0.022036
# sqft_living15    0.585241
# sqft_lot15       0.082845
# Name: price, dtype: float64

# %%
plt.figure(figsize=(10,6))
sns.displot(data['sqft_lot15'])
plt.xlim(0,200000)
# Out:
# (0.0, 200000.0)

# %%
sns.scatterplot(x='sqft_living',y='price',data=df)
# Out:
# <AxesSubplot:xlabel='sqft_living', ylabel='price'>

# %%
plt.figure(figsize=(10,6))
sns.countplot(x=df['bedrooms'])
# Out:
# <AxesSubplot:xlabel='bedrooms', ylabel='count'>

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='bedrooms',y='price',data=df)
# Out:
# <AxesSubplot:xlabel='bedrooms', ylabel='price'>

# %%
sns.scatterplot(x='lat',y='price',data=df)
#seems to be 122 has some costlier houses
# Out:
# <AxesSubplot:xlabel='lat', ylabel='price'>

# %%
sns.scatterplot(x='long',y='price',data=df)
#seems to be 122 has some costlier houses
# Out:
# <AxesSubplot:xlabel='long', ylabel='price'>

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='long',y='lat',data=df,hue='price',edgecolor=None,palette='RdYlGn')#depicts the actual mapt
#there are some outliers we need to remove it
# Out:
# <AxesSubplot:xlabel='long', ylabel='lat'>

# %%
len(df)*0.01
# Out:
# 215.97

# %%
bottom99per=df.sort_values('price',ascending=False).iloc[216:]

# %%
bottom99per.head()#highest-2 m
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 6329    824059321    6/2/2014  1970000.0         4       3.50         4370
# 12271  1923000260  10/15/2014  1960000.0         5       4.50         6200
# 9166   3124059023   2/13/2015  1960000.0         3       1.75         3330
# 12565  2806300065   4/22/2015  1960000.0         4       4.00         4430
# 1150   4055701200   4/21/2015  1960000.0         4       2.75         3120
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 6329       8510     2.0           0     1  ...     10        3610
# 12271     23373     3.0           0     1  ...     11        5050
# 9166      12566     1.0           1     4  ...      8        1940
# 12565     31353     2.0           0     0  ...     12        4430
# 1150       7898     1.0           1     4  ...      8        1560
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='long',y='lat',hue='price',data=bottom99per,edgecolor=None,alpha=0.2,palette='RdYlGn')
#houses nesr water bodies arre seems to be cotlier
# Out:
# <AxesSubplot:xlabel='long', ylabel='lat'>

# %%
sns.boxplot(x='waterfront',y='price',data=df)
# Out:
# <AxesSubplot:xlabel='waterfront', ylabel='price'>

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
df=df.drop('id',axis=1)

# %%
df['date']
# Out:
# 0        10/13/2014
# 1         12/9/2014
# 2         2/25/2015
# 3         12/9/2014
# 4         2/18/2015
#             ...
# 21592     5/21/2014
# 21593     2/23/2015
# 21594     6/23/2014
# 21595     1/16/2015
# 21596    10/15/2014
# Name: date, Length: 21597, dtype: object

# %%
df['date']=pd.to_datetime(df['date'])

# %%
df['month']=df['date'].apply(lambda a:a.month)

# %%
df['year']=df['date'].apply(lambda a:a.year)

# %%
df.head()
# Out:
#         date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0 2014-10-13  221900.0         3       1.00         1180      5650     1.0
# 1 2014-12-09  538000.0         3       2.25         2570      7242     2.0
# 2 2015-02-25  180000.0         2       1.00          770     10000     1.0
# 3 2014-12-09  604000.0         4       3.00         1960      5000     1.0
# 4 2015-02-18  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  sqft_basement  yr_built  yr_renovated  \
# 0           0     0          3  ...              0      1955             0
# 1           0     0          3  ...            400      1951          1991
# 2           0     0          3  ...              0      1933             0
# 3           0     0          5  ...            910      1965             0
# 4           0     0          3  ...              0      1987             0
#
# ...

# %%
df['date']
#dtype
# Out:
# 0       2014-10-13
# 1       2014-12-09
# 2       2015-02-25
# 3       2014-12-09
# 4       2015-02-18
#            ...
# 21592   2014-05-21
# 21593   2015-02-23
# 21594   2014-06-23
# 21595   2015-01-16
# 21596   2014-10-15
# Name: date, Length: 21597, dtype: datetime64[ns]

# %%
sns.boxplot(x=df['month'],y=df['price'])
#for minute date use groupby
# Out:
# <AxesSubplot:xlabel='month', ylabel='price'>

# %%
df.groupby('month').mean()['price'].plot()
# Out:
# <AxesSubplot:xlabel='month'>

# %%
df.groupby('year').mean()['price'].plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
df=df.drop('date',axis=1)

# %%
df['zipcode'].value_counts()#70
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'zipcode'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-102-1dcfd151df25> in <module>
# ...

# %%
df=df.drop('zipcode',axis=1)#since its a category and has 70 category so its not possible to get_dummies

# %%
df['yr_renovated']#eventhough it is a categorical data..incrs in yr(latest yr) renovated increases rate ..so we keep it as it is
# Out:
# 0           0
# 1        1991
# 2           0
# 3           0
# 4           0
#          ...
# 21592       0
# 21593       0
# 21594       0
# 21595       0
# 21596       0
# Name: yr_renovated, Length: 21597, dtype: int64

# %%
#same for sqft_basement yr_built

# %%
x=df.drop('price',axis=1).values
y=df['price'].values

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=101)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
sc=MinMaxScaler()

# %%
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
sq=Sequential()

# %%
x_train.shape
# Out:
# (15117, 19)

# %%
sq.add(Dense(19,activation='relu'))

# %%
sq.add(Dense(19,activation='relu'))
sq.add(Dense(19,activation='relu'))
sq.add(Dense(19,activation='relu'))
sq.add(Dense(1))

# %%
sq.compile(loss='mse',optimizer='adam')

# %%
sq.fit(x_train,y_train,epochs=400,validation_data=(x_test,y_test),batch_size=128)#validation data is validated after each epoch so that
#we can find the overfitted data->val_loss is the loss for test data(both loss are given in sq.history.history )
#batch_size-data are fed in batch wise..smaller the batch size lower is the likelywood to overfit since only small batches are fed
#at once so we can find quickly before overly overfitting
# Out:
# Epoch 1/400
# 119/119 [==============================] - 0s 4ms/step - loss: 430231289856.0000 - val_loss: 418864889856.0000
# Epoch 2/400
# 119/119 [==============================] - 0s 2ms/step - loss: 428612878336.0000 - val_loss: 413399842816.0000
# Epoch 3/400
# 119/119 [==============================] - 0s 2ms/step - loss: 407786061824.0000 - val_loss: 367316271104.0000
# Epoch 4/400
# 119/119 [==============================] - 0s 2ms/step - loss: 315581104128.0000 - val_loss: 226858008576.0000
# Epoch 5/400
# 119/119 [==============================] - 0s 2ms/step - loss: 160662192128.0000 - val_loss: 104440512512.0000
# Epoch 6/400
# 119/119 [==============================] - 0s 2ms/step - loss: 100621205504.0000 - val_loss: 94643945472.0000
# Epoch 7/400
# 119/119 [==============================] - 0s 2ms/step - loss: 97003864064.0000 - val_loss: 93046325248.0000
# Epoch 8/400
# ...

# %%
his=pd.DataFrame(sq.history.history)

# %%
pd.DataFrame(sq.history.history).plot()#val_loss is the loss in test data...if it overfits there would be a spike in graph
#technically we can continue training more becoz we didnt overfit yet...but its good enough for now
# Out:
# <AxesSubplot:>

# %%
pred=sq.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,explained_variance_score

# %%
mean_absolute_error(y_test,pred)
# Out:
# 100578.49157503858

# %%
mean_squared_error(y_test,pred)**0.5
# Out:
# 163712.73891772784

# %%
#prediction is not good enough becoz of using all data which includes out liers
#so use the same prediction with bottom 99 percent

# %%
explained_variance_score(y_test,pred)#tries to fit 80 percent of the data which includes outliers...which leads to huge error
# Out:
# 0.7983650903014281

# %%
pred=pred.reshape(len(pred),)

# %%
sns.scatterplot(y_test,pred)
plt.plot(y_test,y_test,c='r')
# Out:
# C:\Users\Nachi\Anaconda3\envs\tf\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sample=df.drop('price',axis=1).iloc[0].values

# %%
sample=sample.reshape(-1,19)#-1 keep that old dimension along the axis

# %%
st=sc.transform(sample)

# %%
sq.predict(st)
# Out:
# array([[274513.44]], dtype=float32)

# %%
df.iloc[0]['price']
# Out:
# 221900.0
